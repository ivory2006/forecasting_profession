# %%
from sklearn import metrics, cross_validation
from sklearn import datasets
import numpy as np
from treeinterpreter import treeinterpreter as ti
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix
import pandas as pd
from pprint import pprint
from sklearn.model_selection import train_test_split,cross_val_score
import matplotlib.pyplot as plt
df=pd.read_csv('cleantwitter200kdata_300.csv')
samples=df.loc[:,['Openness','Conscientousness','Extraversion','Agreeableness','Emotional_Range','Conversation','Openness to Change','Hedonism','Self-enhancement','Self-transcendence']]
target=df.loc[:,'Profession']
name=['Openness','Conscientousness','Extraversion','Agreeableness','Emotional_Range','Conversation','Openness to Change','Hedonism','Self-enhancement','Self-transcendence']
#cv_folds = cross_validation.StratifiedKFold(target, n_folds=5, shuffle=False, random_state=0)
samples_train,samples_test,target_train,target_test = train_test_split(samples,target,test_size=0.2,random_state=0)
# Out:
# Openness

# %%
#randomforest
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
RF=RandomForestClassifier()
RF.fit(samples_train,target_train)
# target_pred_SL_R=RF.predict(samples_test) #testing dataset
# accuracy_SL_R=accuracy_score(target_test,target_pred_SL_R) #accuracy rate
# randomforest_report=classification_report(target_test,target_pred_SL_R) #report
# lines_RF = randomforest_report.split('\n')
# NewLines_RF=lines_RF[52].split(' ')
# Logistic_precision_RF=float(NewLines_RF[28])
# Logistic_recall_RF=float(NewLines_RF[34])
# Logistic_f1score_RF=float(NewLines_RF[40])
# print ('the RF accuracy score is',accuracy_SL_R)
# print("the RF precision is",Logistic_precision_RF)
# print("the RF recall is",Logistic_recall_RF)
# print("the RF f1score is",Logistic_f1score_RF,'\n')
# print(len(samples_test))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
prediction, bias, contributions = ti.predict(RF,samples_test)
for i in range(len(samples_test)):  
    print("Instance", i)  
    biases=0
    for j in range(49):
        biases=bias[i][j]+biases
    biases_mean=biases/49
    print("bias is:",biases_mean)
    biases_mean=0
    for k in range(10):     
        contributionses=0
        for h in range(0,1,49):
            contributionses=contributions[i][k][h]+contributionses
        contributionses_mean=contributionses/49
        print("the ",name[k],"contributions is:",contributionses_mean) 
        contributionses_mean=0
        contributionses=0
    print ("-"*20)
# Out:
# Instance 0
# bias is: 0.0204081632653
# the  Openness contributions is: -0.00017077471402
# the  Conscientousness contributions is: -3.24068163894e-05
# the  Extraversion contributions is: -0.000102077593772
# the  Agreeableness contributions is: 3.63161061839e-05
# the  Emotional_Range contributions is: -1.21745300261e-05
# the  Conversation contributions is: -0.000206246064009
# the  Openness to Change contributions is: -0.000232169101281
# the  Hedonism contributions is: 7.82819061403e-06
# the  Self-enhancement contributions is: 0.000115100818555
# the  Self-transcendence contributions is: 0.000153709120978
# --------------------
# Instance 1
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000619250559024
# the  Conscientousness contributions is: -0.00040386482953
# the  Extraversion contributions is: 0.00034247953701
# the  Agreeableness contributions is: 0.000222846639371
# the  Emotional_Range contributions is: 0.000456780245669
# the  Conversation contributions is: -0.00183114645932
# the  Openness to Change contributions is: -0.000633823296918
# the  Hedonism contributions is: 0.000235346686283
# the  Self-enhancement contributions is: 0.000363988857564
# the  Self-transcendence contributions is: 0.000185247477679
# --------------------
# Instance 2
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000274105360974
# the  Conscientousness contributions is: 6.68871821638e-05
# the  Extraversion contributions is: -1.06241322863e-06
# the  Agreeableness contributions is: 0.000239091147344
# the  Emotional_Range contributions is: -0.00038187856103
# the  Conversation contributions is: -5.30289865814e-05
# the  Openness to Change contributions is: -0.000210668833309
# the  Hedonism contributions is: 0.000169736265348
# the  Self-enhancement contributions is: -4.3887199022e-05
# the  Self-transcendence contributions is: 4.60221761231e-05
# --------------------
# Instance 3
# bias is: 0.0204081632653
# the  Openness contributions is: -1.71499863432e-05
# the  Conscientousness contributions is: -0.000221248367674
# the  Extraversion contributions is: 6.59346864184e-06
# the  Agreeableness contributions is: 2.37112348355e-05
# the  Emotional_Range contributions is: -4.69831741842e-05
# the  Conversation contributions is: -9.12356144371e-05
# the  Openness to Change contributions is: -1.12014829347e-06
# the  Hedonism contributions is: -0.000174747713532
# the  Self-enhancement contributions is: 0.00018754763111
# the  Self-transcendence contributions is: -0.00010826191329
# --------------------
# Instance 4
# bias is: 0.0204081632653
# the  Openness contributions is: -0.00026015873477
# the  Conscientousness contributions is: -6.01251804592e-05
# the  Extraversion contributions is: -3.97380688088e-05
# the  Agreeableness contributions is: 9.38764011582e-05
# the  Emotional_Range contributions is: -0.00011666744625
# the  Conversation contributions is: 8.20029076841e-05
# the  Openness to Change contributions is: -0.00030607588481
# the  Hedonism contributions is: 8.21106716965e-06
# the  Self-enhancement contributions is: 0.000211420915375
# the  Self-transcendence contributions is: -5.56405594545e-05
# --------------------
# Instance 5
# bias is: 0.0204081632653
# the  Openness contributions is: 7.68115857501e-05
# the  Conscientousness contributions is: 9.74668322416e-06
# the  Extraversion contributions is: -3.59060720861e-05
# the  Agreeableness contributions is: -5.3618219402e-05
# the  Emotional_Range contributions is: -0.000212769526086
# the  Conversation contributions is: -2.61512727224e-05
# the  Openness to Change contributions is: 9.99012349198e-06
# the  Hedonism contributions is: -0.000151253491647
# the  Self-enhancement contributions is: -5.29320034654e-05
# the  Self-transcendence contributions is: -6.81239022414e-06
# --------------------
# Instance 6
# bias is: 0.0204081632653
# the  Openness contributions is: 3.28843064414e-05
# the  Conscientousness contributions is: 0.000163309827176
# the  Extraversion contributions is: 0.000121357921428
# the  Agreeableness contributions is: 0.000318863489859
# the  Emotional_Range contributions is: 0.00196279258022
# the  Conversation contributions is: -0.000275417341548
# the  Openness to Change contributions is: -0.000804026513618
# the  Hedonism contributions is: 1.05416816525e-05
# the  Self-enhancement contributions is: 9.77507167308e-05
# the  Self-transcendence contributions is: -3.01349249792e-05
# --------------------
# Instance 7
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000140098372199
# the  Conscientousness contributions is: 0.000101176885068
# the  Extraversion contributions is: -4.66470244032e-05
# the  Agreeableness contributions is: 0.000707231564543
# the  Emotional_Range contributions is: 0.000178883191756
# the  Conversation contributions is: 0.000247563185805
# the  Openness to Change contributions is: -0.00123368385637
# the  Hedonism contributions is: -0.000649776942858
# the  Self-enhancement contributions is: 1.42291241781e-05
# the  Self-transcendence contributions is: 9.80309169194e-05
# --------------------
# Instance 8
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000190547064916
# the  Conscientousness contributions is: -1.60358355787e-06
# the  Extraversion contributions is: 6.15117172079e-05
# the  Agreeableness contributions is: 4.28130700361e-07
# the  Emotional_Range contributions is: -6.63412837487e-05
# the  Conversation contributions is: -9.24077464314e-05
# the  Openness to Change contributions is: -3.2049163975e-05
# the  Hedonism contributions is: -1.99093638141e-05
# the  Self-enhancement contributions is: -1.91166588664e-05
# the  Self-transcendence contributions is: -8.28595657659e-05
# --------------------
# Instance 9
# bias is: 0.0204081632653
# the  Openness contributions is: -4.04200624052e-05
# the  Conscientousness contributions is: -8.03045482511e-07
# the  Extraversion contributions is: -4.66308616676e-05
# the  Agreeableness contributions is: -6.4859026853e-05
# the  Emotional_Range contributions is: -2.41356343736e-05
# the  Conversation contributions is: -0.000170270787984
# the  Openness to Change contributions is: 3.55540938341e-05
# the  Hedonism contributions is: -1.43621466625e-05
# the  Self-enhancement contributions is: -0.000115713637117
# the  Self-transcendence contributions is: -1.25347445472e-06
# --------------------
# Instance 10
# bias is: 0.0204081632653
# the  Openness contributions is: -3.08989426243e-05
# the  Conscientousness contributions is: -4.225746801e-05
# the  Extraversion contributions is: -9.53665910616e-05
# the  Agreeableness contributions is: -6.2919704452e-05
# the  Emotional_Range contributions is: 1.92934420172e-06
# the  Conversation contributions is: -0.00010475664623
# the  Openness to Change contributions is: 0.0
# the  Hedonism contributions is: -7.69216666325e-05
# the  Self-enhancement contributions is: -1.94089684906e-05
# the  Self-transcendence contributions is: -1.2293939867e-05
# --------------------
# Instance 11
# bias is: 0.0204081632653
# the  Openness contributions is: -8.28135416702e-05
# the  Conscientousness contributions is: -0.000164732027323
# the  Extraversion contributions is: 0.000402731097524
# the  Agreeableness contributions is: 9.68553206839e-05
# the  Emotional_Range contributions is: 7.26172511243e-05
# the  Conversation contributions is: 0.000156128511904
# the  Openness to Change contributions is: -4.17228540939e-05
# the  Hedonism contributions is: -9.81579211125e-05
# the  Self-enhancement contributions is: -0.000976171789472
# the  Self-transcendence contributions is: 0.000192371369269
# --------------------
# Instance 12
# bias is: 0.0204081632653
# the  Openness contributions is: -9.21212613797e-05
# the  Conscientousness contributions is: 4.80121363805e-07
# the  Extraversion contributions is: -3.4962654941e-06
# the  Agreeableness contributions is: -3.82904729794e-05
# the  Emotional_Range contributions is: -3.34649820383e-05
# the  Conversation contributions is: -0.000107140971608
# the  Openness to Change contributions is: -1.88945777018e-05
# the  Hedonism contributions is: -5.46167668658e-05
# the  Self-enhancement contributions is: -2.17497638017e-05
# the  Self-transcendence contributions is: -7.35996426618e-05
# --------------------
# Instance 13
# bias is: 0.0204081632653
# the  Openness contributions is: 0.00014110342808
# the  Conscientousness contributions is: -2.34309758327e-05
# the  Extraversion contributions is: 5.71118809723e-06
# the  Agreeableness contributions is: -0.000238806976203
# the  Emotional_Range contributions is: -7.00310523282e-05
# the  Conversation contributions is: -8.00290954395e-05
# the  Openness to Change contributions is: -3.8920052847e-05
# the  Hedonism contributions is: -0.000110305088816
# the  Self-enhancement contributions is: -2.0663875498e-05
# the  Self-transcendence contributions is: -7.52208237997e-06
# --------------------
# Instance 14
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000359003983787
# the  Conscientousness contributions is: 8.40871588869e-05
# the  Extraversion contributions is: 1.31503687265e-05
# the  Agreeableness contributions is: -6.73295661175e-05
# the  Emotional_Range contributions is: 0.000221312609683
# the  Conversation contributions is: -0.00028321511981
# the  Openness to Change contributions is: -0.000312609404433
# the  Hedonism contributions is: 7.78714129247e-05
# the  Self-enhancement contributions is: 0.000144277359102
# the  Self-transcendence contributions is: 3.85645816583e-05
# --------------------
# Instance 15
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000259348063629
# the  Conscientousness contributions is: -0.000921321082075
# the  Extraversion contributions is: 0.000164219940249
# the  Agreeableness contributions is: -0.000200838252028
# the  Emotional_Range contributions is: 0.000282618130411
# the  Conversation contributions is: -0.000580309369772
# the  Openness to Change contributions is: 8.94811605155e-06
# the  Hedonism contributions is: 0.000669118657595
# the  Self-enhancement contributions is: 0.000281291916604
# the  Self-transcendence contributions is: 0.000112725423426
# --------------------
# Instance 16
# bias is: 0.0204081632653
# the  Openness contributions is: -4.8825263475e-05
# the  Conscientousness contributions is: -2.28647290157e-05
# the  Extraversion contributions is: -7.70534068537e-05
# the  Agreeableness contributions is: -8.96026195115e-05
# the  Emotional_Range contributions is: 2.17262161399e-05
# the  Conversation contributions is: -4.33201101254e-05
# the  Openness to Change contributions is: -5.44832280295e-05
# the  Hedonism contributions is: -3.96710649172e-05
# the  Self-enhancement contributions is: -2.01117824943e-05
# the  Self-transcendence contributions is: -6.86885948843e-05
# --------------------
# Instance 17
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000521460290412
# the  Conscientousness contributions is: -2.06895488761e-05
# the  Extraversion contributions is: -0.000418051407011
# the  Agreeableness contributions is: -1.63153929247e-05
# the  Emotional_Range contributions is: -6.7606288984e-05
# the  Conversation contributions is: -0.000146239868361
# the  Openness to Change contributions is: 0.000194002550546
# the  Hedonism contributions is: 0.000527866428673
# the  Self-enhancement contributions is: 0.000161415793041
# the  Self-transcendence contributions is: -0.000135816558858
# --------------------
# Instance 18
# bias is: 0.0204081632653
# the  Openness contributions is: -7.64337453278e-05
# the  Conscientousness contributions is: -5.72854524491e-05
# the  Extraversion contributions is: -4.68189922399e-05
# the  Agreeableness contributions is: 1.68652466067e-05
# the  Emotional_Range contributions is: -6.69402701302e-05
# the  Conversation contributions is: -0.000103816416184
# the  Openness to Change contributions is: -1.55869618815e-06
# the  Hedonism contributions is: -5.43474901774e-05
# the  Self-enhancement contributions is: -2.71444272819e-05
# the  Self-transcendence contributions is: -2.5414339795e-05
# --------------------
# Instance 19
# bias is: 0.0204081632653
# the  Openness contributions is: 5.74661389524e-06
# the  Conscientousness contributions is: -4.65828417689e-06
# the  Extraversion contributions is: -6.83466674384e-05
# the  Agreeableness contributions is: -5.78238948129e-05
# the  Emotional_Range contributions is: -0.000131475499006
# the  Conversation contributions is: -5.97303289215e-05
# the  Openness to Change contributions is: -9.7037367666e-06
# the  Hedonism contributions is: -6.82418620467e-05
# the  Self-enhancement contributions is: -3.22672947871e-05
# the  Self-transcendence contributions is: -1.63936291057e-05
# --------------------
# Instance 20
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000185265791064
# the  Conscientousness contributions is: -1.18992415544e-05
# the  Extraversion contributions is: 1.36136326857e-05
# the  Agreeableness contributions is: -2.0200392562e-05
# the  Emotional_Range contributions is: 8.16692949373e-05
# the  Conversation contributions is: -0.000126945975793
# the  Openness to Change contributions is: 1.65419267118e-05
# the  Hedonism contributions is: -7.74768131967e-05
# the  Self-enhancement contributions is: -3.1086428288e-05
# the  Self-transcendence contributions is: -0.000101844795044
# --------------------
# Instance 21
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000835355851631
# the  Conscientousness contributions is: 0.00010521078672
# the  Extraversion contributions is: -0.00021971508799
# the  Agreeableness contributions is: 0.000146325263982
# the  Emotional_Range contributions is: -3.63621197174e-05
# the  Conversation contributions is: 0.000291097741428
# the  Openness to Change contributions is: 0.000184379798515
# the  Hedonism contributions is: -0.000175189729736
# the  Self-enhancement contributions is: 0.000589727728395
# the  Self-transcendence contributions is: -0.000122908489864
# --------------------
# Instance 22
# bias is: 0.0204081632653
# the  Openness contributions is: -4.68999499594e-05
# the  Conscientousness contributions is: -0.00010494875619
# the  Extraversion contributions is: 0.000435624919449
# the  Agreeableness contributions is: 5.17730770142e-05
# the  Emotional_Range contributions is: -9.1593605237e-05
# the  Conversation contributions is: -0.00120243489505
# the  Openness to Change contributions is: 6.67704123165e-05
# the  Hedonism contributions is: -1.90249103702e-05
# the  Self-enhancement contributions is: 9.31546416004e-06
# the  Self-transcendence contributions is: 0.000458523660698
# --------------------
# Instance 23
# bias is: 0.0204081632653
# the  Openness contributions is: -5.23642685098e-05
# the  Conscientousness contributions is: -6.16429470787e-06
# the  Extraversion contributions is: -6.88087820796e-06
# the  Agreeableness contributions is: -2.25875894223e-05
# the  Emotional_Range contributions is: -3.11799595125e-05
# the  Conversation contributions is: -6.75189088678e-05
# the  Openness to Change contributions is: -0.000160579586672
# the  Hedonism contributions is: -4.51383232874e-05
# the  Self-enhancement contributions is: -2.95182543008e-05
# the  Self-transcendence contributions is: -2.09625196778e-05
# --------------------
# Instance 24
# bias is: 0.0204081632653
# the  Openness contributions is: -7.10820063571e-05
# the  Conscientousness contributions is: -0.00187450653381
# the  Extraversion contributions is: 0.000473150538146
# the  Agreeableness contributions is: -0.00189146247553
# the  Emotional_Range contributions is: -0.000754658631353
# the  Conversation contributions is: 0.000523965636304
# the  Openness to Change contributions is: 0.000464165855053
# the  Hedonism contributions is: 0.00125713245464
# the  Self-enhancement contributions is: 0.000278399354319
# the  Self-transcendence contributions is: 0.00115200122542
# --------------------
# Instance 25
# bias is: 0.0204081632653
# the  Openness contributions is: -0.00016352413801
# the  Conscientousness contributions is: -2.32885561204e-05
# the  Extraversion contributions is: -7.66118174051e-05
# the  Agreeableness contributions is: 2.15468808774e-05
# the  Emotional_Range contributions is: -3.59064174724e-05
# the  Conversation contributions is: -2.23863272578e-05
# the  Openness to Change contributions is: 2.99145616501e-05
# the  Hedonism contributions is: -0.000161683339356
# the  Self-enhancement contributions is: -1.74613487338e-05
# the  Self-transcendence contributions is: 6.50591866179e-06
# --------------------
# Instance 26
# bias is: 0.0204081632653
# the  Openness contributions is: 9.6921546283e-05
# the  Conscientousness contributions is: -0.000216872926334
# the  Extraversion contributions is: -4.11210425689e-05
# the  Agreeableness contributions is: 8.06158908429e-06
# the  Emotional_Range contributions is: -9.73692044716e-05
# the  Conversation contributions is: 9.02090839397e-05
# the  Openness to Change contributions is: -0.000103233954524
# the  Hedonism contributions is: -0.000113117998784
# the  Self-enhancement contributions is: -7.22029502014e-05
# the  Self-transcendence contributions is: 5.83127440956e-06
# --------------------
# Instance 27
# bias is: 0.0204081632653
# the  Openness contributions is: -6.21648811123e-05
# the  Conscientousness contributions is: 2.78112737433e-06
# the  Extraversion contributions is: -3.6738888218e-05
# the  Agreeableness contributions is: -4.54217866985e-05
# the  Emotional_Range contributions is: -5.19613937991e-05
# the  Conversation contributions is: -2.62637420369e-05
# the  Openness to Change contributions is: -4.89874146412e-06
# the  Hedonism contributions is: -8.18937199369e-05
# the  Self-enhancement contributions is: -0.000105637362918
# the  Self-transcendence contributions is: -3.06951943576e-05
# --------------------
# Instance 28
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000181433125651
# the  Conscientousness contributions is: 8.25687384017e-05
# the  Extraversion contributions is: 0.000245274925287
# the  Agreeableness contributions is: -0.000785455937875
# the  Emotional_Range contributions is: 0.000108439404403
# the  Conversation contributions is: -9.44452576819e-05
# the  Openness to Change contributions is: -0.000165417271147
# the  Hedonism contributions is: 0.000106380347854
# the  Self-enhancement contributions is: -5.75535370119e-05
# the  Self-transcendence contributions is: 0.000298747130254
# --------------------
# Instance 29
# bias is: 0.0204081632653
# the  Openness contributions is: 9.6921546283e-05
# the  Conscientousness contributions is: -9.31870883621e-05
# the  Extraversion contributions is: -4.11210425689e-05
# the  Agreeableness contributions is: -0.000115624248887
# the  Emotional_Range contributions is: -9.73692044716e-05
# the  Conversation contributions is: 9.02090839397e-05
# the  Openness to Change contributions is: -0.000103233954524
# the  Hedonism contributions is: -0.000113117998784
# the  Self-enhancement contributions is: -7.22029502014e-05
# the  Self-transcendence contributions is: 5.83127440956e-06
# --------------------
# Instance 30
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000109154004817
# the  Conscientousness contributions is: -8.5367975969e-06
# the  Extraversion contributions is: 6.34184478402e-05
# the  Agreeableness contributions is: -9.30216260545e-05
# the  Emotional_Range contributions is: -0.000210785976432
# the  Conversation contributions is: -5.50777993447e-05
# the  Openness to Change contributions is: -4.28541241902e-05
# the  Hedonism contributions is: -0.000135595374663
# the  Self-enhancement contributions is: -6.27829473185e-05
# the  Self-transcendence contributions is: -6.81239022414e-06
# --------------------
# Instance 31
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000175818066634
# the  Conscientousness contributions is: -7.03395306365e-05
# the  Extraversion contributions is: -8.92010262553e-05
# the  Agreeableness contributions is: -3.04763963819e-05
# the  Emotional_Range contributions is: 8.70036402861e-05
# the  Conversation contributions is: 5.2152998227e-05
# the  Openness to Change contributions is: -8.20272066993e-06
# the  Hedonism contributions is: -0.00012660726347
# the  Self-enhancement contributions is: -0.000208157633804
# the  Self-transcendence contributions is: 0.000126751416171
# --------------------
# Instance 32
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000192551963745
# the  Conscientousness contributions is: 4.7956305958e-07
# the  Extraversion contributions is: 3.48874281642e-05
# the  Agreeableness contributions is: -6.05737372154e-05
# the  Emotional_Range contributions is: 2.3068855107e-05
# the  Conversation contributions is: 2.13001889765e-05
# the  Openness to Change contributions is: 6.02226580064e-06
# the  Hedonism contributions is: -0.000121071783329
# the  Self-enhancement contributions is: -0.000150479801352
# the  Self-transcendence contributions is: -3.97559863331e-06
# --------------------
# Instance 33
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000167232613046
# the  Conscientousness contributions is: 0.000103055480115
# the  Extraversion contributions is: 0.000293723506507
# the  Agreeableness contributions is: -0.00159187247504
# the  Emotional_Range contributions is: 0.000537795780201
# the  Conversation contributions is: 0.000565976442714
# the  Openness to Change contributions is: -4.55854267843e-05
# the  Hedonism contributions is: -0.000186916277956
# the  Self-enhancement contributions is: 1.68930540869e-05
# the  Self-transcendence contributions is: 3.12679460383e-05
# --------------------
# Instance 34
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000211647306992
# the  Conscientousness contributions is: 3.50882767653e-05
# the  Extraversion contributions is: -7.74891028135e-05
# the  Agreeableness contributions is: -0.000360342347535
# the  Emotional_Range contributions is: 3.31360399435e-05
# the  Conversation contributions is: -0.000672031957815
# the  Openness to Change contributions is: 2.11524989565e-06
# the  Hedonism contributions is: 3.45952287816e-05
# the  Self-enhancement contributions is: 0.000262609522997
# the  Self-transcendence contributions is: 8.77771996222e-05
# --------------------
# Instance 35
# bias is: 0.0204081632653
# the  Openness contributions is: 3.34005181242e-05
# the  Conscientousness contributions is: 0.000112883252544
# the  Extraversion contributions is: -0.000155326982764
# the  Agreeableness contributions is: 6.0208921914e-05
# the  Emotional_Range contributions is: 0.000111927144539
# the  Conversation contributions is: -8.67579719431e-05
# the  Openness to Change contributions is: -0.000138884741348
# the  Hedonism contributions is: -0.000276545577124
# the  Self-enhancement contributions is: -4.75226612641e-05
# the  Self-transcendence contributions is: -5.6276485844e-05
# --------------------
# Instance 36
# bias is: 0.0204081632653
# the  Openness contributions is: 0.00188935544695
# the  Conscientousness contributions is: 0.0012663662477
# the  Extraversion contributions is: 0.00189138327654
# the  Agreeableness contributions is: 0.00403164150272
# the  Emotional_Range contributions is: 0.00254272315854
# the  Conversation contributions is: 0.000711528480821
# the  Openness to Change contributions is: 0.00201554347088
# the  Hedonism contributions is: 0.00116747841478
# the  Self-enhancement contributions is: 0.00142770388304
# the  Self-transcendence contributions is: 0.00302154480015
# --------------------
# Instance 37
# bias is: 0.0204081632653
# the  Openness contributions is: -1.6792138971e-05
# the  Conscientousness contributions is: -7.70801668894e-05
# the  Extraversion contributions is: -1.79192953915e-05
# the  Agreeableness contributions is: 4.87566034e-05
# the  Emotional_Range contributions is: -7.20057467039e-05
# the  Conversation contributions is: 0.00012878751143
# the  Openness to Change contributions is: -0.000117204713013
# the  Hedonism contributions is: 5.71063864526e-05
# the  Self-enhancement contributions is: -0.000652725352085
# the  Self-transcendence contributions is: 0.000276182328605
# --------------------
# Instance 38
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000411882985144
# the  Conscientousness contributions is: 3.96808640832e-05
# the  Extraversion contributions is: 3.1226273856e-05
# the  Agreeableness contributions is: -4.37485371795e-05
# the  Emotional_Range contributions is: -0.000246283000676
# the  Conversation contributions is: 9.63421322182e-05
# the  Openness to Change contributions is: 1.51653221051e-05
# the  Hedonism contributions is: 0.000105031535
# the  Self-enhancement contributions is: 4.09536099956e-05
# the  Self-transcendence contributions is: -6.93797974251e-05
# --------------------
# Instance 39
# bias is: 0.0204081632653
# the  Openness contributions is: -3.69021168286e-05
# the  Conscientousness contributions is: 3.29613751516e-05
# the  Extraversion contributions is: 1.25767870329e-05
# the  Agreeableness contributions is: -2.56205867067e-05
# the  Emotional_Range contributions is: -0.000101564301561
# the  Conversation contributions is: -3.59378635405e-05
# the  Openness to Change contributions is: -2.84364913868e-06
# the  Hedonism contributions is: -0.000151246771427
# the  Self-enhancement contributions is: -5.24316822503e-05
# the  Self-transcendence contributions is: -8.18857738994e-05
# --------------------
# Instance 40
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000134040403585
# the  Conscientousness contributions is: -6.0759202971e-05
# the  Extraversion contributions is: 3.04787903429e-05
# the  Agreeableness contributions is: -1.64262003082e-05
# the  Emotional_Range contributions is: -0.000149238156803
# the  Conversation contributions is: -2.81850819907e-05
# the  Openness to Change contributions is: -2.58749938218e-05
# the  Hedonism contributions is: -2.65692519187e-05
# the  Self-enhancement contributions is: -2.57879357444e-08
# the  Self-transcendence contributions is: -3.2254294175e-05
# --------------------
# Instance 41
# bias is: 0.0204081632653
# the  Openness contributions is: -8.75543183493e-05
# the  Conscientousness contributions is: -4.84070831008e-05
# the  Extraversion contributions is: -4.81290248967e-05
# the  Agreeableness contributions is: 5.5951506238e-06
# the  Emotional_Range contributions is: -7.6078314372e-06
# the  Conversation contributions is: -0.000182086239885
# the  Openness to Change contributions is: 8.33070843219e-06
# the  Hedonism contributions is: -3.47430421772e-05
# the  Self-enhancement contributions is: -6.94974976647e-05
# the  Self-transcendence contributions is: 2.12045952877e-05
# --------------------
# Instance 42
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000719619225746
# the  Conscientousness contributions is: 1.39231163881e-05
# the  Extraversion contributions is: 2.36852045668e-06
# the  Agreeableness contributions is: -0.000150409005415
# the  Emotional_Range contributions is: 4.58361347786e-06
# the  Conversation contributions is: 0.000367358891334
# the  Openness to Change contributions is: 4.85698119173e-05
# the  Hedonism contributions is: -0.000445079375446
# the  Self-enhancement contributions is: 0.000286692133275
# the  Self-transcendence contributions is: 0.000148716936591
# --------------------
# Instance 43
# bias is: 0.0204081632653
# the  Openness contributions is: -7.72942674749e-05
# the  Conscientousness contributions is: 0.00118679520447
# the  Extraversion contributions is: -9.58507275315e-06
# the  Agreeableness contributions is: 0.000139478344701
# the  Emotional_Range contributions is: -0.00119988967118
# the  Conversation contributions is: -0.000338441693261
# the  Openness to Change contributions is: 0.000602336606214
# the  Hedonism contributions is: 0.000550160765217
# the  Self-enhancement contributions is: 0.000441413761056
# the  Self-transcendence contributions is: 0.000302947766375
# --------------------
# Instance 44
# bias is: 0.0204081632653
# the  Openness contributions is: 2.72255104115e-05
# the  Conscientousness contributions is: 0.00024089488664
# the  Extraversion contributions is: 0.000439990467012
# the  Agreeableness contributions is: 5.99188073429e-05
# the  Emotional_Range contributions is: -0.000525947587804
# the  Conversation contributions is: 0.000424491621844
# the  Openness to Change contributions is: -6.17556600042e-05
# the  Hedonism contributions is: 0.000208993074827
# the  Self-enhancement contributions is: -0.00075024827597
# the  Self-transcendence contributions is: -0.000506457427466
# --------------------
# Instance 45
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000338272655103
# the  Conscientousness contributions is: 9.13758021162e-05
# the  Extraversion contributions is: 0.000116479787319
# the  Agreeableness contributions is: -0.000239367335123
# the  Emotional_Range contributions is: -0.000245521654685
# the  Conversation contributions is: 0.000179859743612
# the  Openness to Change contributions is: -5.44706183458e-05
# the  Hedonism contributions is: 0.000124856042625
# the  Self-enhancement contributions is: -8.85447566874e-05
# the  Self-transcendence contributions is: 1.07110611054e-05
# --------------------
# Instance 46
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000803171407472
# the  Conscientousness contributions is: 0.000266781779618
# the  Extraversion contributions is: 2.43830945135e-05
# the  Agreeableness contributions is: 5.78485455015e-05
# the  Emotional_Range contributions is: -1.04219675842e-05
# the  Conversation contributions is: 0.000200518187041
# the  Openness to Change contributions is: 2.00965668252e-05
# the  Hedonism contributions is: -5.27712125784e-05
# the  Self-enhancement contributions is: -3.89879269003e-05
# the  Self-transcendence contributions is: -0.000107170242131
# --------------------
# Instance 47
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000352862656929
# the  Conscientousness contributions is: 0.000117961657867
# the  Extraversion contributions is: 7.98265251126e-05
# the  Agreeableness contributions is: 2.15524508263e-05
# the  Emotional_Range contributions is: -7.38264992431e-05
# the  Conversation contributions is: -0.000349147698221
# the  Openness to Change contributions is: -0.00036729530584
# the  Hedonism contributions is: -0.000215294255145
# the  Self-enhancement contributions is: -9.85513335282e-06
# the  Self-transcendence contributions is: 3.21017900285e-07
# --------------------
# Instance 48
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000172431758436
# the  Conscientousness contributions is: -1.75445318397e-05
# the  Extraversion contributions is: -8.72706416966e-05
# the  Agreeableness contributions is: 0.00011638224274
# the  Emotional_Range contributions is: -0.000122595038803
# the  Conversation contributions is: 7.02881479042e-05
# the  Openness to Change contributions is: -0.000248859338857
# the  Hedonism contributions is: -0.000403148881477
# the  Self-enhancement contributions is: 0.000261742590136
# the  Self-transcendence contributions is: -0.000184320889709
# --------------------
# Instance 49
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000598614915769
# the  Conscientousness contributions is: -0.000762023669793
# the  Extraversion contributions is: -0.000366667764901
# the  Agreeableness contributions is: 0.000358860066031
# the  Emotional_Range contributions is: 0.000246651145457
# the  Conversation contributions is: 0.000173971809436
# the  Openness to Change contributions is: -0.000348280405226
# the  Hedonism contributions is: 0.000152530700287
# the  Self-enhancement contributions is: 8.56227754337e-05
# the  Self-transcendence contributions is: -0.000582174155661
# --------------------
# Instance 50
# bias is: 0.0204081632653
# the  Openness contributions is: -4.27656453043e-05
# the  Conscientousness contributions is: -0.000649133450516
# the  Extraversion contributions is: -0.000664579432326
# the  Agreeableness contributions is: -0.000113398514819
# the  Emotional_Range contributions is: 0.000380605399024
# the  Conversation contributions is: 6.90721379257e-06
# the  Openness to Change contributions is: 0.000495691583015
# the  Hedonism contributions is: 0.000639304882604
# the  Self-enhancement contributions is: 2.04016742183e-05
# the  Self-transcendence contributions is: -0.000515928292855
# --------------------
# Instance 51
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000202035393045
# the  Conscientousness contributions is: -0.000215253083703
# the  Extraversion contributions is: -0.000284516892468
# the  Agreeableness contributions is: -3.27354462343e-07
# the  Emotional_Range contributions is: -4.6453241031e-06
# the  Conversation contributions is: -2.11652524811e-05
# the  Openness to Change contributions is: 6.52225660033e-05
# the  Hedonism contributions is: 0.000165097809454
# the  Self-enhancement contributions is: 0.000173770158426
# the  Self-transcendence contributions is: -0.000119041816788
# --------------------
# Instance 52
# bias is: 0.0204081632653
# the  Openness contributions is: 1.33278618197e-05
# the  Conscientousness contributions is: -1.3853586158e-05
# the  Extraversion contributions is: -5.55404908817e-05
# the  Agreeableness contributions is: 8.75214357795e-05
# the  Emotional_Range contributions is: -0.000140437108727
# the  Conversation contributions is: 4.03201477494e-05
# the  Openness to Change contributions is: -7.89400137481e-05
# the  Hedonism contributions is: -0.000119637582639
# the  Self-enhancement contributions is: -0.000147148682797
# the  Self-transcendence contributions is: -2.85065635638e-05
# --------------------
# Instance 53
# bias is: 0.0204081632653
# the  Openness contributions is: 6.58298813193e-06
# the  Conscientousness contributions is: 1.97878057853e-05
# the  Extraversion contributions is: 1.46652255582e-05
# the  Agreeableness contributions is: 3.36190505551e-05
# the  Emotional_Range contributions is: 1.5252210616e-05
# the  Conversation contributions is: -4.44739385906e-05
# the  Openness to Change contributions is: 3.54932323818e-05
# the  Hedonism contributions is: -0.000271634114046
# the  Self-enhancement contributions is: -0.000143566760668
# the  Self-transcendence contributions is: -0.00010862028289
# --------------------
# Instance 54
# bias is: 0.0204081632653
# the  Openness contributions is: 3.88864792865e-07
# the  Conscientousness contributions is: 8.85420136257e-05
# the  Extraversion contributions is: -0.000219133559207
# the  Agreeableness contributions is: -0.000306637437158
# the  Emotional_Range contributions is: 0.000198070140495
# the  Conversation contributions is: -0.000253630651167
# the  Openness to Change contributions is: -9.73194717616e-05
# the  Hedonism contributions is: 0.000222445932342
# the  Self-enhancement contributions is: -7.31561614448e-05
# the  Self-transcendence contributions is: -2.46425368367e-06
# --------------------
# Instance 55
# bias is: 0.0204081632653
# the  Openness contributions is: -9.55063996255e-05
# the  Conscientousness contributions is: 5.40187140562e-05
# the  Extraversion contributions is: 6.02639976828e-05
# the  Agreeableness contributions is: -0.000149693680539
# the  Emotional_Range contributions is: -4.63165898039e-05
# the  Conversation contributions is: -4.46153836999e-05
# the  Openness to Change contributions is: -1.36140374928e-05
# the  Hedonism contributions is: 0.000138217492581
# the  Self-enhancement contributions is: -7.39606381266e-05
# the  Self-transcendence contributions is: -0.000271688058198
# --------------------
# Instance 56
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000106574923186
# the  Conscientousness contributions is: 6.26714362388e-05
# the  Extraversion contributions is: -2.64601340071e-05
# the  Agreeableness contributions is: 2.47711740896e-05
# the  Emotional_Range contributions is: -0.000157321196669
# the  Conversation contributions is: -3.37297964454e-05
# the  Openness to Change contributions is: 7.56261546161e-05
# the  Hedonism contributions is: -0.000230915422602
# the  Self-enhancement contributions is: -9.82418384847e-05
# the  Self-transcendence contributions is: 4.72799632831e-05
# --------------------
# Instance 57
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000108210495119
# the  Conscientousness contributions is: 2.9748964278e-05
# the  Extraversion contributions is: -4.27116643689e-05
# the  Agreeableness contributions is: 1.20817188739e-05
# the  Emotional_Range contributions is: -9.17902424219e-05
# the  Conversation contributions is: 3.3495025098e-05
# the  Openness to Change contributions is: -0.000297049576624
# the  Hedonism contributions is: -9.44105991351e-05
# the  Self-enhancement contributions is: 2.33154894204e-05
# the  Self-transcendence contributions is: -0.000123784193406
# --------------------
# Instance 58
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000183630615004
# the  Conscientousness contributions is: -5.65039634741e-05
# the  Extraversion contributions is: 5.87715306529e-05
# the  Agreeableness contributions is: -1.8347107681e-05
# the  Emotional_Range contributions is: -0.000113320853872
# the  Conversation contributions is: -3.54535755127e-05
# the  Openness to Change contributions is: 1.29212566911e-05
# the  Hedonism contributions is: -5.54228953579e-05
# the  Self-enhancement contributions is: -9.93753584837e-05
# the  Self-transcendence contributions is: 4.74669988752e-05
# --------------------
# Instance 59
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000246199278517
# the  Conscientousness contributions is: -1.58544776315e-05
# the  Extraversion contributions is: 4.45151610174e-05
# the  Agreeableness contributions is: -7.39020423447e-05
# the  Emotional_Range contributions is: 4.40725871372e-05
# the  Conversation contributions is: 0.000253393187423
# the  Openness to Change contributions is: -0.000108300131028
# the  Hedonism contributions is: 0.00023492819032
# the  Self-enhancement contributions is: -0.0010618927019
# the  Self-transcendence contributions is: -6.05363467558e-06
# --------------------
# Instance 60
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000187585169647
# the  Conscientousness contributions is: -0.000744945867019
# the  Extraversion contributions is: -0.000360750562708
# the  Agreeableness contributions is: 0.000163342487187
# the  Emotional_Range contributions is: 0.000268079328701
# the  Conversation contributions is: -2.21007006378e-05
# the  Openness to Change contributions is: -7.84813353331e-05
# the  Hedonism contributions is: 0.000144571739081
# the  Self-enhancement contributions is: -0.000341628521298
# the  Self-transcendence contributions is: 0.000341433679212
# --------------------
# Instance 61
# bias is: 0.0204081632653
# the  Openness contributions is: 0.00102248957598
# the  Conscientousness contributions is: 0.00268103944782
# the  Extraversion contributions is: 0.00145018874766
# the  Agreeableness contributions is: 0.00167340000444
# the  Emotional_Range contributions is: 0.00269909610851
# the  Conversation contributions is: 0.00344198485483
# the  Openness to Change contributions is: 0.000643010066864
# the  Hedonism contributions is: 0.00249740858841
# the  Self-enhancement contributions is: 0.00152042370501
# the  Self-transcendence contributions is: 0.00233622758261
# --------------------
# Instance 62
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000116837324759
# the  Conscientousness contributions is: 5.69540200661e-06
# the  Extraversion contributions is: -8.17067353792e-05
# the  Agreeableness contributions is: -6.0003037693e-05
# the  Emotional_Range contributions is: -0.000185130757007
# the  Conversation contributions is: -5.29290245129e-06
# the  Openness to Change contributions is: 7.65239334073e-05
# the  Hedonism contributions is: -7.42792958919e-05
# the  Self-enhancement contributions is: -3.07988448566e-05
# the  Self-transcendence contributions is: 2.89349794571e-05
# --------------------
# Instance 63
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000438499716709
# the  Conscientousness contributions is: -2.67864721775e-05
# the  Extraversion contributions is: 0.000123865753288
# the  Agreeableness contributions is: 0.000159086011582
# the  Emotional_Range contributions is: -0.000449305396428
# the  Conversation contributions is: 0.000211590227947
# the  Openness to Change contributions is: -3.04248002948e-05
# the  Hedonism contributions is: -0.000811383541832
# the  Self-enhancement contributions is: 7.07394233511e-05
# the  Self-transcendence contributions is: -0.000128775505311
# --------------------
# Instance 64
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000162566194042
# the  Conscientousness contributions is: -8.84174662033e-06
# the  Extraversion contributions is: -4.40942395412e-05
# the  Agreeableness contributions is: -9.48301213519e-05
# the  Emotional_Range contributions is: -7.83027687411e-05
# the  Conversation contributions is: -0.000150101002337
# the  Openness to Change contributions is: -6.32172569927e-05
# the  Hedonism contributions is: -0.000109817894701
# the  Self-enhancement contributions is: 0.000150311153276
# the  Self-transcendence contributions is: -0.000206566900199
# --------------------
# Instance 65
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000219632857032
# the  Conscientousness contributions is: -5.43233076023e-05
# the  Extraversion contributions is: 2.89569382598e-05
# the  Agreeableness contributions is: 0.000274511653991
# the  Emotional_Range contributions is: -0.000204092888212
# the  Conversation contributions is: -5.95454132009e-05
# the  Openness to Change contributions is: 5.26216503135e-06
# the  Hedonism contributions is: 0.000117450364368
# the  Self-enhancement contributions is: -0.000459177854487
# the  Self-transcendence contributions is: 0.000127696615717
# --------------------
# Instance 66
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000887497127519
# the  Conscientousness contributions is: -0.000230955029206
# the  Extraversion contributions is: 0.000201610546723
# the  Agreeableness contributions is: 0.000295591263051
# the  Emotional_Range contributions is: -0.000585977280693
# the  Conversation contributions is: -0.000298424081825
# the  Openness to Change contributions is: -0.000266657905897
# the  Hedonism contributions is: 0.000301382521436
# the  Self-enhancement contributions is: -9.70444640723e-05
# the  Self-transcendence contributions is: -0.000649917280204
# --------------------
# Instance 67
# bias is: 0.0204081632653
# the  Openness contributions is: 5.66471459999e-05
# the  Conscientousness contributions is: -2.70876227637e-06
# the  Extraversion contributions is: 6.34727948724e-05
# the  Agreeableness contributions is: 3.81308762585e-05
# the  Emotional_Range contributions is: -6.59704834251e-05
# the  Conversation contributions is: -0.000268762989704
# the  Openness to Change contributions is: -3.16234374602e-05
# the  Hedonism contributions is: -0.000107843573219
# the  Self-enhancement contributions is: -8.3109431028e-06
# the  Self-transcendence contributions is: -0.000115925211111
# --------------------
# Instance 68
# bias is: 0.0204081632653
# the  Openness contributions is: -5.60416591844e-05
# the  Conscientousness contributions is: -1.62169069574e-05
# the  Extraversion contributions is: -1.5937108774e-05
# the  Agreeableness contributions is: -0.000132559599635
# the  Emotional_Range contributions is: 0.000177984284318
# the  Conversation contributions is: -4.4828761402e-05
# the  Openness to Change contributions is: -0.00010159203361
# the  Hedonism contributions is: -9.70443631469e-05
# the  Self-enhancement contributions is: -5.2140399062e-05
# the  Self-transcendence contributions is: -0.000104518035713
# --------------------
# Instance 69
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000143036975049
# the  Conscientousness contributions is: 1.99779986129e-05
# the  Extraversion contributions is: -0.000188903724056
# the  Agreeableness contributions is: 0.000134700054805
# the  Emotional_Range contributions is: -0.000140757033192
# the  Conversation contributions is: 0.000134060545457
# the  Openness to Change contributions is: 1.64227556343e-05
# the  Hedonism contributions is: -0.000428873162766
# the  Self-enhancement contributions is: 5.90690986262e-05
# the  Self-transcendence contributions is: 9.44458587612e-05
# --------------------
# Instance 70
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000625177282118
# the  Conscientousness contributions is: 0.000765931074277
# the  Extraversion contributions is: 0.000130420642728
# the  Agreeableness contributions is: 0.00196394557647
# the  Emotional_Range contributions is: 0.000177184388234
# the  Conversation contributions is: -9.33553290593e-05
# the  Openness to Change contributions is: -0.00142798532503
# the  Hedonism contributions is: 0.000747633327814
# the  Self-enhancement contributions is: 0.000135930580887
# the  Self-transcendence contributions is: -0.00017660591084
# --------------------
# Instance 71
# bias is: 0.0204081632653
# the  Openness contributions is: 5.15528360564e-05
# the  Conscientousness contributions is: -0.00114898510267
# the  Extraversion contributions is: 0.000163565118657
# the  Agreeableness contributions is: -7.2596653874e-05
# the  Emotional_Range contributions is: 0.000162802699757
# the  Conversation contributions is: 0.000248062762715
# the  Openness to Change contributions is: -0.000228446548345
# the  Hedonism contributions is: 0.000242191736314
# the  Self-enhancement contributions is: -5.79164694675e-05
# the  Self-transcendence contributions is: 0.000196875037689
# --------------------
# Instance 72
# bias is: 0.0204081632653
# the  Openness contributions is: -5.64022049248e-05
# the  Conscientousness contributions is: 3.49295039267e-05
# the  Extraversion contributions is: -0.000398371928842
# the  Agreeableness contributions is: 0.000100083953377
# the  Emotional_Range contributions is: 0.000456789365622
# the  Conversation contributions is: -0.000201696664778
# the  Openness to Change contributions is: -3.11681677357e-05
# the  Hedonism contributions is: 0.00028328447182
# the  Self-enhancement contributions is: -0.000487704573785
# the  Self-transcendence contributions is: -0.000142638337845
# --------------------
# Instance 73
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000119502366434
# the  Conscientousness contributions is: 0.000223880410039
# the  Extraversion contributions is: -6.58834516451e-05
# the  Agreeableness contributions is: 9.8370295503e-05
# the  Emotional_Range contributions is: -0.000366771804298
# the  Conversation contributions is: -0.000257810683084
# the  Openness to Change contributions is: -8.61662774097e-05
# the  Hedonism contributions is: 3.17065568685e-06
# the  Self-enhancement contributions is: -8.24501565314e-05
# the  Self-transcendence contributions is: -2.87359378603e-05
# --------------------
# Instance 74
# bias is: 0.0204081632653
# the  Openness contributions is: -5.69561713819e-05
# the  Conscientousness contributions is: -0.000330063006684
# the  Extraversion contributions is: 2.75445091779e-05
# the  Agreeableness contributions is: -4.54034887297e-05
# the  Emotional_Range contributions is: -5.831781144e-05
# the  Conversation contributions is: -0.00010151482777
# the  Openness to Change contributions is: 0.000126009523157
# the  Hedonism contributions is: 8.42218496442e-05
# the  Self-enhancement contributions is: -1.16073706718e-05
# the  Self-transcendence contributions is: -7.68077884681e-05
# --------------------
# Instance 75
# bias is: 0.0204081632653
# the  Openness contributions is: 0.000411161407848
# the  Conscientousness contributions is: -0.000776137987611
# the  Extraversion contributions is: -0.000531799306762
# the  Agreeableness contributions is: 0.000672191023167
# the  Emotional_Range contributions is: 0.000191968277811
# the  Conversation contributions is: 0.000861576330596
# the  Openness to Change contributions is: -0.000184404683596
# the  Hedonism contributions is: 0.000180337317644
# the  Self-enhancement contributions is: -0.00116929484971
# the  Self-transcendence contributions is: -9.84921125575e-05
# --------------------
# Instance 76
# bias is: 0.0204081632653
# the  Openness contributions is: 6.63099663087e-05
# the  Conscientousness contributions is: -0.000113640823832
# the  Extraversion contributions is: -4.04108133732e-06
# the  Agreeableness contributions is: -0.000185552498415
# the  Emotional_Range contributions is: -2.86583651046e-05
# the  Conversation contributions is: -6.18413614037e-05
# the  Openness to Change contributions is: 1.90743640353e-06
# the  Hedonism contributions is: -0.00011501031232
# the  Self-enhancement contributions is: 1.65175571906e-05
# the  Self-transcendence contributions is: -1.88851006562e-05
# --------------------
# Instance 77
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000544345570561
# the  Conscientousness contributions is: 0.000121368292408
# the  Extraversion contributions is: 1.80151074138e-06
# the  Agreeableness contributions is: 5.09950721924e-05
# the  Emotional_Range contributions is: 1.91590123341e-05
# the  Conversation contributions is: -0.000216601670851
# ...
# the  Extraversion contributions is: 0.000323437425415
# the  Agreeableness contributions is: -0.000142026806093
# the  Emotional_Range contributions is: -7.0055271253e-05
# the  Conversation contributions is: -0.000158290370428
# the  Openness to Change contributions is: -2.70482555731e-05
# the  Hedonism contributions is: -8.46886496404e-07
# the  Self-enhancement contributions is: -0.000268549702422
# the  Self-transcendence contributions is: -0.000182014545747
# --------------------
# Instance 3968
# bias is: 0.0204081632653
# the  Openness contributions is: 6.1726185867e-05
# the  Conscientousness contributions is: -0.000558437340849
# the  Extraversion contributions is: 0.000318823118024
# the  Agreeableness contributions is: -0.000180882470392
# the  Emotional_Range contributions is: -0.000101324673569
# the  Conversation contributions is: 3.15026309578e-05
# the  Openness to Change contributions is: 0.000439125137214
# the  Hedonism contributions is: -3.75771046639e-05
# the  Self-enhancement contributions is: -0.000372790147795
# the  Self-transcendence contributions is: -4.30599179614e-05
# --------------------
# Instance 3969
# bias is: 0.0204081632653
# the  Openness contributions is: 3.65396357895e-05
# the  Conscientousness contributions is: 3.12719063872e-06
# the  Extraversion contributions is: -0.000272986234911
# the  Agreeableness contributions is: -0.000171454575552
# the  Emotional_Range contributions is: -6.38208987112e-05
# the  Conversation contributions is: 1.03950660189e-05
# the  Openness to Change contributions is: 5.51545215366e-05
# the  Hedonism contributions is: -9.70890044401e-05
# the  Self-enhancement contributions is: 0.000153483731078
# the  Self-transcendence contributions is: -9.62440146142e-05
# --------------------
# Instance 3970
# bias is: 0.0204081632653
# the  Openness contributions is: -2.90415548084e-05
# the  Conscientousness contributions is: -0.000817353142965
# the  Extraversion contributions is: -0.000136604585574
# the  Agreeableness contributions is: -0.00020895971491
# the  Emotional_Range contributions is: 0.000375371218379
# the  Conversation contributions is: -8.22967569278e-05
# the  Openness to Change contributions is: -3.77171515669e-05
# the  Hedonism contributions is: 0.00048437828879
# the  Self-enhancement contributions is: -3.5517614203e-05
# the  Self-transcendence contributions is: 4.48464306207e-05
# --------------------
# Instance 3971
# bias is: 0.0204081632653
# the  Openness contributions is: 7.66670141223e-05
# the  Conscientousness contributions is: -1.17768276796e-05
# the  Extraversion contributions is: 2.06779079083e-05
# the  Agreeableness contributions is: -9.779412022e-05
# the  Emotional_Range contributions is: -3.88186311978e-05
# the  Conversation contributions is: -9.5778223374e-05
# the  Openness to Change contributions is: -5.33872629122e-05
# the  Hedonism contributions is: -5.01858075209e-05
# the  Self-enhancement contributions is: -4.20906666654e-05
# the  Self-transcendence contributions is: -0.000150407965627
# --------------------
# Instance 3972
# bias is: 0.0204081632653
# the  Openness contributions is: -0.00015091086807
# the  Conscientousness contributions is: 4.5971844613e-06
# the  Extraversion contributions is: -5.22437112909e-05
# the  Agreeableness contributions is: 3.19475323797e-05
# the  Emotional_Range contributions is: -0.00013283357723
# the  Conversation contributions is: -7.76462251897e-05
# the  Openness to Change contributions is: -1.31881359689e-05
# the  Hedonism contributions is: -6.1030723308e-05
# the  Self-enhancement contributions is: -3.85485965691e-05
# the  Self-transcendence contributions is: 4.69625376193e-05
# --------------------
# Instance 3973
# bias is: 0.0204081632653
# the  Openness contributions is: -7.83192977615e-05
# the  Conscientousness contributions is: -0.000161317769756
# the  Extraversion contributions is: 7.04670389483e-05
# the  Agreeableness contributions is: 4.6631644118e-05
# the  Emotional_Range contributions is: 0.000106020105854
# the  Conversation contributions is: -0.000224992680995
# the  Openness to Change contributions is: -9.37982771978e-05
# the  Hedonism contributions is: -5.52359876169e-05
# the  Self-enhancement contributions is: -2.43751624294e-05
# the  Self-transcendence contributions is: -2.79741963297e-05
# --------------------
# Instance 3974
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000217318478271
# the  Conscientousness contributions is: 5.82537188765e-06
# the  Extraversion contributions is: 2.5300247772e-05
# the  Agreeableness contributions is: 4.2922028181e-06
# the  Emotional_Range contributions is: -4.30521355183e-05
# the  Conversation contributions is: -4.47587685588e-05
# the  Openness to Change contributions is: 3.27721515241e-06
# the  Hedonism contributions is: -0.000157110764199
# the  Self-enhancement contributions is: -3.43762934595e-05
# the  Self-transcendence contributions is: 1.50268192099e-05
# --------------------
# Instance 3975
# bias is: 0.0204081632653
# the  Openness contributions is: -7.57842839066e-05
# the  Conscientousness contributions is: 2.78112737433e-06
# the  Extraversion contributions is: -5.0976690539e-05
# the  Agreeableness contributions is: -8.93748714417e-05
# the  Emotional_Range contributions is: 6.39740728344e-06
# the  Conversation contributions is: -9.93576612395e-05
# the  Openness to Change contributions is: 6.93450812059e-07
# the  Hedonism contributions is: -9.18338877825e-05
# the  Self-enhancement contributions is: -3.42890918063e-05
# the  Self-transcendence contributions is: -1.11500819209e-05
# --------------------
# Instance 3976
# bias is: 0.0204081632653
# the  Openness contributions is: 9.6921546283e-05
# the  Conscientousness contributions is: -9.31870883621e-05
# the  Extraversion contributions is: -4.11210425689e-05
# the  Agreeableness contributions is: -0.000115624248887
# the  Emotional_Range contributions is: -9.73692044716e-05
# the  Conversation contributions is: 9.02090839397e-05
# the  Openness to Change contributions is: -0.000103233954524
# the  Hedonism contributions is: -0.000113117998784
# the  Self-enhancement contributions is: -7.22029502014e-05
# the  Self-transcendence contributions is: 5.83127440956e-06
# --------------------
# Instance 3977
# bias is: 0.0204081632653
# the  Openness contributions is: 1.11712826266e-05
# the  Conscientousness contributions is: 0.000112909362111
# the  Extraversion contributions is: 5.47421321258e-05
# the  Agreeableness contributions is: -0.000230840375541
# the  Emotional_Range contributions is: -0.000173610834759
# the  Conversation contributions is: -2.88384114913e-05
# the  Openness to Change contributions is: 3.92161746256e-05
# the  Hedonism contributions is: -0.000430161560854
# the  Self-enhancement contributions is: 3.06075398063e-05
# the  Self-transcendence contributions is: 0.000171910108182
# --------------------
# Instance 3978
# bias is: 0.0204081632653
# the  Openness contributions is: -2.58111374284e-05
# the  Conscientousness contributions is: 4.67638822445e-05
# the  Extraversion contributions is: 3.61503042368e-06
# the  Agreeableness contributions is: -0.000108137265088
# the  Emotional_Range contributions is: -0.000167826244219
# the  Conversation contributions is: -4.12128049168e-05
# the  Openness to Change contributions is: 2.12115401392e-05
# the  Hedonism contributions is: -9.64134565943e-05
# the  Self-enhancement contributions is: -1.67367715662e-05
# the  Self-transcendence contributions is: -5.83473561614e-05
# --------------------
# Instance 3979
# bias is: 0.0204081632653
# the  Openness contributions is: 9.0374564875e-05
# the  Conscientousness contributions is: 0.000146185102867
# the  Extraversion contributions is: 7.97635061739e-05
# the  Agreeableness contributions is: -0.000567413904802
# the  Emotional_Range contributions is: 0.000768422955863
# the  Conversation contributions is: -0.000399217883859
# the  Openness to Change contributions is: 2.55236242277e-05
# the  Hedonism contributions is: -7.5305765842e-05
# the  Self-enhancement contributions is: -0.000124162357036
# the  Self-transcendence contributions is: -0.000387064425634
# --------------------
# Instance 3980
# bias is: 0.0204081632653
# the  Openness contributions is: -4.4779981699e-05
# the  Conscientousness contributions is: -8.91414102145e-05
# the  Extraversion contributions is: -2.26193801551e-05
# the  Agreeableness contributions is: 1.85364501849e-05
# the  Emotional_Range contributions is: -6.09440947015e-05
# the  Conversation contributions is: -6.4118695364e-05
# the  Openness to Change contributions is: -5.03528484662e-06
# the  Hedonism contributions is: -0.000174783010161
# the  Self-enhancement contributions is: -1.76692418882e-05
# the  Self-transcendence contributions is: 1.76600656784e-05
# --------------------
# Instance 3981
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000133857722512
# the  Conscientousness contributions is: -1.60358355787e-06
# the  Extraversion contributions is: 2.17143134806e-05
# the  Agreeableness contributions is: 4.78646400653e-06
# the  Emotional_Range contributions is: -6.86472908973e-05
# the  Conversation contributions is: -0.000103269922181
# the  Openness to Change contributions is: -3.2049163975e-05
# the  Hedonism contributions is: -2.11717256993e-05
# the  Self-enhancement contributions is: -1.93459130138e-05
# the  Self-transcendence contributions is: -8.94500388178e-05
# --------------------
# Instance 3982
# bias is: 0.0204081632653
# the  Openness contributions is: -5.60416591844e-05
# the  Conscientousness contributions is: -1.62169069574e-05
# the  Extraversion contributions is: -1.5937108774e-05
# the  Agreeableness contributions is: -0.000132559599635
# the  Emotional_Range contributions is: 0.000177984284318
# the  Conversation contributions is: -4.4828761402e-05
# the  Openness to Change contributions is: -0.00010159203361
# the  Hedonism contributions is: -9.70443631469e-05
# the  Self-enhancement contributions is: -5.2140399062e-05
# the  Self-transcendence contributions is: -0.000104518035713
# --------------------
# Instance 3983
# bias is: 0.0204081632653
# the  Openness contributions is: -9.6555668713e-05
# the  Conscientousness contributions is: -3.74689722068e-05
# the  Extraversion contributions is: 1.55932382437e-05
# the  Agreeableness contributions is: -4.20411595256e-05
# the  Emotional_Range contributions is: -4.77269958487e-05
# the  Conversation contributions is: -8.1801774987e-05
# the  Openness to Change contributions is: 1.63533774265e-05
# the  Hedonism contributions is: -6.10786621807e-05
# the  Self-enhancement contributions is: -3.27888690653e-05
# the  Self-transcendence contributions is: -7.53790963097e-05
# --------------------
# Instance 3984
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000151571934465
# the  Conscientousness contributions is: -2.9153939197e-05
# the  Extraversion contributions is: -4.2855639309e-05
# the  Agreeableness contributions is: -0.000120616318934
# the  Emotional_Range contributions is: -8.86941876129e-05
# the  Conversation contributions is: -0.000211963944585
# the  Openness to Change contributions is: -0.000535162378463
# the  Hedonism contributions is: 0.000497932612499
# the  Self-enhancement contributions is: 0.000120972110782
# the  Self-transcendence contributions is: 0.00011821903612
# --------------------
# Instance 3985
# bias is: 0.0204081632653
# the  Openness contributions is: 4.01012930405e-05
# the  Conscientousness contributions is: 0.000116542236854
# the  Extraversion contributions is: 5.40154947606e-05
# the  Agreeableness contributions is: -6.11111390179e-05
# the  Emotional_Range contributions is: -0.000337831929192
# the  Conversation contributions is: -0.0005010055206
# the  Openness to Change contributions is: -9.84730368729e-05
# the  Hedonism contributions is: 0.000186265694242
# the  Self-enhancement contributions is: 0.000257615638871
# the  Self-transcendence contributions is: -9.90133152523e-05
# --------------------
# Instance 3986
# bias is: 0.0204081632653
# the  Openness contributions is: -6.89049893649e-05
# the  Conscientousness contributions is: 1.05325892759e-05
# the  Extraversion contributions is: 1.55932382437e-05
# the  Agreeableness contributions is: 2.62267543509e-06
# the  Emotional_Range contributions is: 5.84431814187e-05
# the  Conversation contributions is: -0.000156201506886
# the  Openness to Change contributions is: -5.39126637042e-06
# the  Hedonism contributions is: -5.49624596803e-05
# the  Self-enhancement contributions is: -5.3772304201e-05
# the  Self-transcendence contributions is: -0.000190853741037
# --------------------
# Instance 3987
# bias is: 0.0204081632653
# the  Openness contributions is: 5.96800122531e-05
# the  Conscientousness contributions is: 0.000186983147631
# the  Extraversion contributions is: 9.41519242413e-06
# the  Agreeableness contributions is: -4.30234431452e-06
# the  Emotional_Range contributions is: -4.38589730512e-05
# the  Conversation contributions is: -7.38734358247e-05
# the  Openness to Change contributions is: 0.000140845001536
# the  Hedonism contributions is: -0.000826559385628
# the  Self-enhancement contributions is: 2.3653925373e-06
# the  Self-transcendence contributions is: 0.000106410809271
# --------------------
# Instance 3988
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000181096334693
# the  Conscientousness contributions is: 3.85964672309e-06
# the  Extraversion contributions is: 3.36791859691e-05
# the  Agreeableness contributions is: 6.27236043677e-06
# the  Emotional_Range contributions is: 3.18148248347e-06
# the  Conversation contributions is: -9.89472514208e-05
# the  Openness to Change contributions is: 1.33694784833e-05
# the  Hedonism contributions is: -0.000125847239219
# the  Self-enhancement contributions is: -3.41389065622e-05
# the  Self-transcendence contributions is: -6.3227005367e-05
# --------------------
# Instance 3989
# bias is: 0.0204081632653
# the  Openness contributions is: -0.000123238929808
# the  Conscientousness contributions is: 1.50230799936e-05
# the  Extraversion contributions is: 1.8809409751e-06
# the  Agreeableness contributions is: -2.59028842137e-05
# the  Emotional_Range contributions is: -6.71960404782e-05
# the  Conversation contributions is: -5.97363266287e-05
# the  Openness to Change contributions is: -5.93751382769e-06
# the  Hedonism contributions is: -0.000117136054094
# the  Self-enhancement contributions is: -7.33555591321e-05
# the  Self-transcendence contributions is: 1.27047040466e-05
# --------------------
# Instance 3990
# bias is: 0.0204081632653
# the  Openness contributions is: -8.38398043502e-05
# the  Conscientousness contributions is: 4.58277188761e-05
# the  Extraversion contributions is: -0.000162955173737
# the  Agreeableness contributions is: 1.41301943569e-05
# the  Emotional_Range contributions is: -4.82080794235e-05
# the  Conversation contributions is: -2.4965617702e-05
# the  Openness to Change contributions is: 2.71862002238e-05
# the  Hedonism contributions is: -8.20407537971e-05
# the  Self-enhancement contributions is: -2.25680310535e-05
# the  Self-transcendence contributions is: -0.00010546123656
# --------------------
# Instance 3991
# bias is: 0.0204081632653
# the  Openness contributions is: 9.98311140002e-05
# the  Conscientousness contributions is: -0.000226724636753
# the  Extraversion contributions is: -0.000120437442731
# the  Agreeableness contributions is: 1.87043090187e-05
# the  Emotional_Range contributions is: -6.85183683221e-05
# the  Conversation contributions is: -3.31541726354e-05
# the  Openness to Change contributions is: 8.3462554916e-05
# the  Hedonism contributions is: -0.000189553374761
# the  Self-enhancement contributions is: 8.13392650909e-05
# the  Self-transcendence contributions is: -8.78438309904e-05
# --------------------
# Instance 3992
# bias is: 0.0204081632653
# the  Openness contributions is: -7.45977703055e-05
# the  Conscientousness contributions is: 6.05973170971e-05
# the  Extraversion contributions is: -0.000133457421196
# the  Agreeableness contributions is: 1.41060212728e-05
# the  Emotional_Range contributions is: -2.91041076426e-05
# the  Conversation contributions is: -0.000189473843067
# the  Openness to Change contributions is: -3.38530809891e-06
# the  Hedonism contributions is: -5.43474901774e-05
# the  Self-enhancement contributions is: -1.56437120053e-05
# the  Self-transcendence contributions is: -1.7588269044e-05
# --------------------

# %%
from treeinterpreter import treeinterpreter as ti
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import numpy as np
 
from sklearn.datasets import load_boston
boston = load_boston()
rf = RandomForestRegressor()
rf.fit(boston.data[:300], boston.target[:300])
instances = boston.data[[300, 309]]
print (rf.predict(instances[0]))
print (rf.predict(instances[1]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-509dabbd5322> in <module>()
#       8 rf = RandomForestRegressor()
#       9 rf.fit(boston.data[:300], boston.target[:300])
# ---> 10 instances = boston.data[300, 309]
#      11 print (rf.predict(instances[0]))
#      12 print (rf.predict(instances[1]))
#
# IndexError: index 309 is out of bounds for axis 1 with size 13
