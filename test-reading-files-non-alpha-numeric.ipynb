# %%
import codecs
f = open("4.txt", "r")
s = f.read()
print(s)
# Out:
# ﻿@fox when do you get in?RT @ctrlaltjustine: I believe it's vital for all not-engineer tech folk to remember on days like today:
#
# ...

# %%
print ''.join(ch for ch in s if ch.isalnum())
# Out:
# ...

# %%
import re
string = "Kl13@£$%[};'\""
pattern = re.compile('\W')
string = re.sub(pattern, '', s)
print string
# Out:
# foxwhendoyougetinRTctrlaltjustineIbelieveitsvitalforallnotengineertechfolktorememberondaysliketodayYOURACCOMPLISHMENTSAREIMPORTArkh_...
